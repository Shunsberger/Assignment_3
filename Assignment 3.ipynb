# %%
import pandas as pd
from pandas.tools.plotting import scatter_matrix
# %matplotlib inline

# %% [markdown]
# # Part 1
#
# Reads iris.txt into a data frame

# %%
# Assigning pd.read_csv('iris.txt') will allow a quicker call of the iris.txt data
data = pd.read_csv('iris.txt')
data
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth      Species
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# # Part 2-1
#
# Prints the head of the data set iris.txt

# %%
data.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth      Species
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# # Part 2-2
#
# Prints the tail of the data set iris.txt

# %%
data.tail()
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica

# %% [markdown]
# # Part 2-3
#
# Prints summary statistics of iris.txt

# %%
data.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %% [markdown]
# # Part 2-4
#
# Generates a box plot for the data iris.txt

# %%
data.boxplot()
# Out:
# C:\Users\Shane Hunsberger\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':
# {'boxes': [<matplotlib.lines.Line2D at 0xac5c7f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0xac63be0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0xac6fb38>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xac69c50>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0xac5ca90>,
# ...
#   <matplotlib.lines.Line2D at 0xac9df98>]}

# %% [markdown]
# # Part 2-5
#
# Generates a line plot for the data iris.txt

# %%
data.plot()

# %% [markdown]
# # Part 2-6
#
# Generates a histogram for the data iris.txt

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000AD51400>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AE41F28>]], dtype=object)

# %% [markdown]
# # Part 3
#
# Groups the data in iris.txt by the species column

# %%
species = data.groupby('Species')

# %% [markdown]
# # Part 3-1
#
# Prints the summary statistics for each species in iris.txt

# %%
species.describe()
# Out:
#                        PetalLength  PetalWidth  SepalLength  SepalWidth
# Species
# Iris-setosa     count    50.000000   50.000000    50.000000   50.000000
#                 mean      1.464000    0.244000     5.006000    3.418000
#                 std       0.173511    0.107210     0.352490    0.381024
#                 min       1.000000    0.100000     4.300000    2.300000
#                 25%       1.400000    0.200000     4.800000    3.125000
#                 50%       1.500000    0.200000     5.000000    3.400000
#                 75%       1.575000    0.300000     5.200000    3.675000
#                 max       1.900000    0.600000     5.800000    4.400000
# Iris-versicolor count    50.000000   50.000000    50.000000   50.000000
#                 mean      4.260000    1.326000     5.936000    2.770000
#                 std       0.469911    0.197753     0.516171    0.313798
#                 min       3.000000    1.000000     4.900000    2.000000
# ...

# %% [markdown]
# # Part 3-2
#
# Generates a boxplot for each species in iris.txt

# %%
species.boxplot()
# Out:
# C:\Users\Shane Hunsberger\Anaconda3\lib\site-packages\pandas\tools\plotting.py:3082: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   rot=rot, grid=grid, **kwds)
# OrderedDict([('Iris-setosa',
#               {'boxes': [<matplotlib.lines.Line2D at 0xb4ce668>,
# ...
#                'caps': [<matplotlib.lines.Line2D at 0xb48acc0>,
# ...
#                'fliers': [<matplotlib.lines.Line2D at 0xb4dcb00>,
# ...
#                'means': [],
#                'medians': [<matplotlib.lines.Line2D at 0xb4d6c18>,
# ...
#                'whiskers': [<matplotlib.lines.Line2D at 0xb4ced68>,
# ...
#                 <matplotlib.lines.Line2D at 0xb719f60>]}),
#              ('Iris-versicolor',
#               {'boxes': [<matplotlib.lines.Line2D at 0xb72e588>,
# ...
#                'caps': [<matplotlib.lines.Line2D at 0xb72eb00>,
# ...

# %% [markdown]
# # Part 3-3
#
# Generates a scatter matrix for the dataset

# %%
scatter_matrix(data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000B8478D0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CC487B8>]], dtype=object)
